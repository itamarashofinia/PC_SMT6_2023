# %% [markdown]
# <a href="https://colab.research.google.com/github/itamarashofinia/PC_SMT6_2023/blob/main/PC_Modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Modul 2**

# %% [markdown]
# **1. Citra dengan channel warna BGM**

# %%
from google.colab import drive

# Accessing my Google Drive
drive.mount('/content/drive')

import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg')
plt.imshow(img) #Perhatikan hasilnya adalah citra dgn channel warna BGM
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **2. Citra dengan channel warna BGR**

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# **3. Menampilkan citra grayscale, melakukan resizing dan flipping, serta menyimpan citra hasil**

# %%
img_gray = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#Simpan file image
#cv.imwrite('/content/drive/MyDrive/PC/gemoy.jpg', img5)

#Tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# **4. Membuat bentuk geometri 2D yang diawali dengan membuat black image**

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img)

# %%
# Perhatikan koordinat pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Shofin Cantik', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **E. TUGAS**

# %% [markdown]
# **1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Membaca gambar dari disk
img = cv2.imread("gemoy.jpg")

# Memisahkan gambar menjadi channel Red, Green, dan Blue
b,g,r = cv2.split(img)

# Menampilkan channel Red-Green
cv2_imshow(np.dstack((r,g,np.zeros_like(b))))

# Menampilkan channel Green-Blue
cv2_imshow(np.dstack((np.zeros_like(r),g,b)))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7FDC18E99460>
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7FDC1878A2E0>

# %% [markdown]
# **2. Tampilkan image baris ke 10-100, kolom 10-100!**

# %%
img_tg2 = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg')
plt.imshow(img_tg2[10:100,10:100])

# %% [markdown]
# **3. Tampilan image baris ke 5-30, semua kolom, channel Green saja!**

# %%
img_tg3 = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_tg3[5:30], cmap='Greens')

# %% [markdown]
# **6. Buatlah rectangle dan circle pada bagian wajah dari image kitten!**

# %%
img_tg6 = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg')

cv.rectangle(img_tg6,pt1=(300,300),pt2=(500,500),color=(0,255,0),thickness=5)
cv.circle(img_tg6,center=(400,400),radius=50,color=(255,0,0),thickness=5)
plt.imshow(img_tg6)

# %% [markdown]
# **7. Buatlah rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten!**

# %%
img_tg7 = cv.imread('/content/drive/MyDrive/PC/gemoy.jpg')
img_rgb7 = cv.cvtColor(img_tg7, cv.COLOR_BGR2RGB)

cv.rectangle(img_rgb7,pt1=(0,900),pt2=(100,800),color=(0,255,0),thickness=5)
plt.imshow(img_rgb7)
